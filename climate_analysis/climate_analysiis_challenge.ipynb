# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import extract

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Calculate the date one year from the last date in data set.
prev_years = dt.date(2017, 8, 23) - dt.timedelta(days=9999)
# Perform a query to retrieve the data and precipitation scores
results = []
results = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date)==6).all()
# Save the query results as a Pandas DataFrame and set the index to the date column
rain_june_df = pd.DataFrame(results, columns=['date','precipitation'])
# Sort the dataframe by date
rain_june_df.set_index(rain_june_df['date'], inplace=True)
rain_june_df = rain_june_df.sort_index()
print(rain_june_df.to_string(index=False))
# Use Pandas Plotting with Matplotlib to plot the data
rain_june_df.plot()
# Out:
#        date  precipitation
#  2010-06-01           0.00
#  2010-06-01           0.01
#  2010-06-01           0.00
#  2010-06-01            NaN
#  2010-06-01           0.03
#  2010-06-01           0.00
#  2010-06-01           0.00
#  2010-06-01           0.08
#  2010-06-01           0.03
#  2010-06-02           0.00
#  2010-06-02           0.03
#  2010-06-02           0.00
#  2010-06-02           0.00
#  2010-06-02           0.03
#  2010-06-02           0.00
#  2010-06-02           0.00
#  2010-06-02           0.00
#  2010-06-02           0.01
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-03           0.10
#  2010-06-03           0.00
#  2010-06-03           0.14
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.01
# ...

# %%
rain_june_df.describe()
# Out:
#        precipitation
# count    1574.000000
# mean        0.136360
# std         0.335731
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.120000
# max         4.430000

# %%
# Calculate the date one year from the last date in data set.
prev_years = dt.date(2017, 8, 23) - dt.timedelta(days=9999)
# Perform a query to retrieve the data and precipitation scores
results = []
results = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date)==12).all()
# Save the query results as a Pandas DataFrame and set the index to the date column
rain_dec_df = pd.DataFrame(results, columns=['date','precipitation'])
# Sort the dataframe by date
rain_dec_df.set_index(rain_dec_df['date'], inplace=True)
rain_dec_df = rain_dec_df.sort_index()
print(rain_dec_df.to_string(index=False))
# Use Pandas Plotting with Matplotlib to plot the data
rain_dec_df.plot()
# Out:
#        date  precipitation
#  2010-12-01           0.04
#  2010-12-01           0.03
#  2010-12-01           0.70
#  2010-12-01           0.03
#  2010-12-01           1.35
#  2010-12-01           0.13
#  2010-12-01           1.48
#  2010-12-01           0.76
#  2010-12-02            NaN
#  2010-12-02           0.16
#  2010-12-02           0.06
#  2010-12-02           0.26
#  2010-12-02           0.00
#  2010-12-02           0.13
#  2010-12-02           0.02
#  2010-12-02           0.18
#  2010-12-03           1.59
#  2010-12-03           0.01
#  2010-12-03           0.78
#  2010-12-03           0.00
#  2010-12-03           0.22
#  2010-12-03           0.01
#  2010-12-03           0.47
#  2010-12-03           0.16
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-04           0.19
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-05           0.00
#  2010-12-05           0.00
# ...

# %%
rain_dec_df.describe()
# Out:
#        precipitation
# count    1405.000000
# mean        0.216819
# std         0.541399
# min         0.000000
# 25%         0.000000
# 50%         0.030000
# 75%         0.150000
# max         6.420000

# %%
# Calculate the date one year from the last date in data set.
prev_years = dt.date(2017, 8, 23) - dt.timedelta(days=9999)
# Perform a query to retrieve the data and precipitation scores
results = []
results = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==6).all()
# Save the query results as a Pandas DataFrame and set the index to the date column
temp_june_df = pd.DataFrame(results, columns=['date','temperature'])
# Sort the dataframe by date
temp_june_df.set_index(temp_june_df['date'], inplace=True)
temp_june_df = temp_june_df.sort_index()
print(temp_june_df.to_string(index=False))
# Use Pandas Plotting with Matplotlib to plot the data
temp_june_df.plot()
# Out:
#        date  temperature
#  2010-06-01         78.0
#  2010-06-01         73.0
#  2010-06-01         77.0
#  2010-06-01         69.0
#  2010-06-01         76.0
#  2010-06-01         71.0
#  2010-06-01         74.0
#  2010-06-01         70.0
#  2010-06-01         74.0
#  2010-06-02         78.0
#  2010-06-02         70.0
#  2010-06-02         76.0
#  2010-06-02         76.0
#  2010-06-02         71.0
#  2010-06-02         76.0
#  2010-06-02         76.0
#  2010-06-02         72.0
#  2010-06-02         76.0
#  2010-06-03         74.0
#  2010-06-03         78.0
#  2010-06-03         73.0
#  2010-06-03         72.0
#  2010-06-03         77.0
#  2010-06-03         76.0
#  2010-06-03         75.0
#  2010-06-03         78.0
#  2010-06-03         67.0
#  2010-06-04         73.0
#  2010-06-04         75.0
#  2010-06-04         75.0
#  2010-06-04         76.0
#  2010-06-04         73.0
#  2010-06-04         68.0
#  2010-06-04         72.0
#  2010-06-04         70.0
#  2010-06-04         74.0
# ...

# %%
temp_june_df.describe()
# Out:
#        temperature
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %%
# Calculate the date one year from the last date in data set.
prev_years = dt.date(2017, 8, 23) - dt.timedelta(days=9999)
# Perform a query to retrieve the data and precipitation scores
results = []
results = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==12).all()
# Save the query results as a Pandas DataFrame and set the index to the date column
temp_dec_df = pd.DataFrame(results, columns=['date','temperature'])
# Sort the dataframe by date
temp_dec_df.set_index(temp_dec_df['date'], inplace=True)
temp_dec_df = temp_dec_df.sort_index()
print(temp_dec_df.to_string(index=False))
# Use Pandas Plotting with Matplotlib to plot the data
temp_dec_df.plot()
# Out:
#        date  temperature
#  2010-12-01         76.0
#  2010-12-01         73.0
#  2010-12-01         72.0
#  2010-12-01         78.0
#  2010-12-01         72.0
#  2010-12-01         70.0
#  2010-12-01         71.0
#  2010-12-01         73.0
#  2010-12-02         71.0
#  2010-12-02         71.0
#  2010-12-02         73.0
#  2010-12-02         75.0
#  2010-12-02         74.0
#  2010-12-02         72.0
#  2010-12-02         74.0
#  2010-12-02         70.0
#  2010-12-03         67.0
#  2010-12-03         74.0
#  2010-12-03         70.0
#  2010-12-03         74.0
#  2010-12-03         71.0
#  2010-12-03         74.0
#  2010-12-03         72.0
#  2010-12-03         73.0
#  2010-12-04         75.0
#  2010-12-04         72.0
#  2010-12-04         77.0
#  2010-12-04         74.0
#  2010-12-04         74.0
#  2010-12-04         78.0
#  2010-12-04         74.0
#  2010-12-05         66.0
#  2010-12-05         69.0
#  2010-12-05         71.0
#  2010-12-05         78.0
#  2010-12-05         73.0
# ...

# %%
temp_dec_df.describe()
# Out:
#        temperature
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000
